# %% [markdown]
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/logo_MCV_W.png)
#
# # **Regularisation in PyTorch - Part 1**
# ### **First we train a CNN on the Fashion-MNIST Dataset usng NO Regularisation Methods**
#
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/CleanShot%202020-12-02%20at%204.01.54%402x.png)
# ---
#
#
#
# ---
#
#
# In this lesson, we first learn to create a **simple Convolutional Neural Network model** in PyTorch and train it to **classify images in the Fashion-MNIST Dataset**, without the use of any regularisation methods.
# 1. Import PyTorch libraries, define our Transformers, Load our dataset and Visualize our images.
# 2. Build a Simple CNN without Regularisation
# 3. Train Our CNN
# 3. Take a look at Data Augmentation

# %% [markdown]
# # **Import PyTorch libraries, Define Transfomers and Load & Visualise Dataset**

# %%
# Import PyTorch
import torch
import PIL

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
device = 'cuda' #'cpu' if no GPU available
# Out:
# GPU available: True

# %% [markdown]
# ### **Our Data Transform**

# %%
# Transform to a PyTorch tensors and the normalize our valeus between -1 and +1
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize((0.5, ), (0.5, )) ])

# %%
# Load our Training Data and specify what transform to use when loading
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=transform)

# Load our Test Data and specify what transform to use when loading
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data\FashionMNIST\raw\train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:06<00:00, 4193073.62it/s]
# Extracting ./data\FashionMNIST\raw\train-images-idx3-ubyte.gz to ./data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw\train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 510900.98it/s]
# Extracting ./data\FashionMNIST\raw\train-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3336921.37it/s]
# Extracting ./data\FashionMNIST\raw\t10k-images-idx3-ubyte.gz to ./data\FashionMNIST\raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<?, ?it/s]
# Extracting ./data\FashionMNIST\raw\t10k-labels-idx1-ubyte.gz to ./data\FashionMNIST\raw

# %%
# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

# Create a list with our class names
classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
# We have 60,000 Image samples for our training data & 10,000 for our test data
# each 28 x 28 pixels, as they are grayscale, there is no 3rd dimension to our image
print(trainset.data.shape)
print(testset.data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %% [markdown]
# ### **Visualising Our Data**

# %%
# Let's view the 50 first images of the MNIST training dataset
import matplotlib.pyplot as plt

figure = plt.figure()
num_of_images = 50 

for index in range(1, num_of_images + 1):
    plt.subplot(5, 10, index)
    plt.axis('off')
    plt.imshow(trainset.data[index], cmap='gray_r')

# %%
import matplotlib.pyplot as plt
import numpy as np
import torchvision
import torch

# Assuming you have defined 'trainloader' and 'classes' somewhere in your code

# function to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# get some random training images
dataiter = iter(trainloader)
images, labels = next(dataiter)

# show images
imshow(torchvision.utils.make_grid(images))

# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(len(labels))))
# Out:
# Shirt Sneaker   Bag Dress Ankle boot Shirt Sandal Sandal Sneaker Dress Sneaker Ankle boot Dress Shirt Sandal T-shirt/top T-shirt/top Ankle boot Dress Trouser   Bag Trouser   Bag T-shirt/top Ankle boot Ankle boot Dress Pullover Sandal Trouser Ankle boot Pullover

# %% [markdown]
# # **2. Building and Training Our Simple CNN with No Regularisation**
#
# #### **Defining Our Model**

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        self.conv2 = nn.Conv2d(32, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %% [markdown]
# #### **Defining our Loss and Optimisation Functions**

# %%
# We import our optimizer function
import torch.optim as optim

# We use Cross Entropy Loss as our loss function
criterion = nn.CrossEntropyLoss()

# For our gradient descent algorthim or Optimizer
# We use Stochastic Gradient Descent (SGD) with a learning rate of 0.001
# We set the momentum to be 0.9
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # **3. Training Our Model**

# %%
# We loop over the traing dataset multiple times (each time is called an epoch)
epochs = 15

# Create some empty arrays to store logs 
epoch_log = []
loss_log = []
accuracy_log = []

# Iterate for a specified number of epochs
for epoch in range(epochs):  
    print(f'Starting Epoch: {epoch+1}...')

    # We keep adding or accumulating our loss after each mini-batch in running_loss
    running_loss = 0.0

    # We iterate through our trainloader iterator
    # Each cycle is a minibatch
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Move our data to GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Clear the gradients before training by setting to zero
        # Required for a fresh start
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation 
        loss = criterion(outputs, labels) # Get Loss (quantify the difference between the results and predictions)
        loss.backward() # Back propagate to obtain the new gradients for all nodes
        optimizer.step() # Update the gradients/weights

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # show our loss every 50 mini-batches
            correct = 0 # Initialize our variable to hold the count for the correct predictions
            total = 0 # Initialize our variable to hold the count of the number of labels iterated

            # We don't need gradients for validation, so wrap in 
            # no_grad to save memory
            with torch.no_grad():
                # Iterate through the testloader iterator
                for data in testloader:
                    images, labels = data
                    # Move our data to GPU
                    images = images.to(device)
                    labels = labels.to(device)
                    
                    # Foward propagate our test data batch through our model
                    outputs = net(images)

                     # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    # Keep adding the label size or length to the total variable
                    total += labels.size(0)
                    # Keep a running total of the number of predictions predicted correctly
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 3.864, Test Accuracy = 61.080%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 1.856, Test Accuracy = 71.140%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.481, Test Accuracy = 74.630%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.313, Test Accuracy = 73.610%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.292, Test Accuracy = 76.220%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.222, Test Accuracy = 76.180%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.215, Test Accuracy = 77.980%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.240, Test Accuracy = 77.080%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.166, Test Accuracy = 78.420%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.073, Test Accuracy = 79.690%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 1.116, Test Accuracy = 80.210%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.079, Test Accuracy = 79.380%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 1.060, Test Accuracy = 80.350%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 1.045, Test Accuracy = 80.510%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 0.996, Test Accuracy = 79.970%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 1.000, Test Accuracy = 81.560%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 1.004, Test Accuracy = 81.870%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 0.989, Test Accuracy = 81.810%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 0.873, Test Accuracy = 81.300%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 0.936, Test Accuracy = 81.990%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 0.898, Test Accuracy = 81.150%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 0.920, Test Accuracy = 83.410%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 0.858, Test Accuracy = 83.520%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 0.885, Test Accuracy = 83.740%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 0.874, Test Accuracy = 83.890%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 0.867, Test Accuracy = 84.350%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 0.834, Test Accuracy = 84.200%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 0.865, Test Accuracy = 84.020%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 0.868, Test Accuracy = 83.410%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 0.818, Test Accuracy = 84.270%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 0.774, Test Accuracy = 84.980%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 0.827, Test Accuracy = 85.000%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 0.766, Test Accuracy = 84.910%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 0.785, Test Accuracy = 84.940%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 0.784, Test Accuracy = 84.530%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 0.807, Test Accuracy = 84.570%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 0.776, Test Accuracy = 85.350%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 0.754, Test Accuracy = 85.860%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 0.727, Test Accuracy = 84.900%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 0.787, Test Accuracy = 85.420%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 0.757, Test Accuracy = 86.290%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 0.710, Test Accuracy = 86.280%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 0.750, Test Accuracy = 86.390%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 0.743, Test Accuracy = 86.520%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 0.728, Test Accuracy = 85.280%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 0.701, Test Accuracy = 85.950%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 0.722, Test Accuracy = 86.290%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 0.716, Test Accuracy = 85.980%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 0.728, Test Accuracy = 86.280%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 0.677, Test Accuracy = 87.230%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 0.657, Test Accuracy = 86.150%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 0.699, Test Accuracy = 87.100%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 0.687, Test Accuracy = 86.650%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 0.703, Test Accuracy = 86.650%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 0.654, Test Accuracy = 87.330%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 0.680, Test Accuracy = 86.140%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.615, Test Accuracy = 86.870%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 0.629, Test Accuracy = 87.640%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 0.676, Test Accuracy = 87.650%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.614, Test Accuracy = 87.340%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 0.679, Test Accuracy = 87.990%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 0.645, Test Accuracy = 87.420%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 0.670, Test Accuracy = 87.840%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 0.647, Test Accuracy = 88.000%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 0.616, Test Accuracy = 88.120%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.618, Test Accuracy = 88.150%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.672, Test Accuracy = 87.830%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.645, Test Accuracy = 88.060%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 0.633, Test Accuracy = 87.410%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 0.619, Test Accuracy = 87.690%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.594, Test Accuracy = 87.690%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.644, Test Accuracy = 87.840%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 0.610, Test Accuracy = 88.480%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.571, Test Accuracy = 87.710%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.588, Test Accuracy = 88.620%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.555, Test Accuracy = 88.590%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.606, Test Accuracy = 88.740%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.635, Test Accuracy = 88.510%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.559, Test Accuracy = 88.380%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.566, Test Accuracy = 88.060%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.606, Test Accuracy = 88.430%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.546, Test Accuracy = 88.360%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.574, Test Accuracy = 88.080%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.573, Test Accuracy = 88.090%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.583, Test Accuracy = 88.290%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.617, Test Accuracy = 88.810%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.601, Test Accuracy = 88.880%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.555, Test Accuracy = 89.170%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.611, Test Accuracy = 89.040%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.542, Test Accuracy = 88.270%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.564, Test Accuracy = 88.860%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0.527, Test Accuracy = 89.290%
# Epoch: 6, Mini-Batches Completed: 300, Loss: 0.565, Test Accuracy = 89.160%
# Epoch: 6, Mini-Batches Completed: 400, Loss: 0.522, Test Accuracy = 88.160%
# Epoch: 6, Mini-Batches Completed: 500, Loss: 0.546, Test Accuracy = 87.710%
# Epoch: 6, Mini-Batches Completed: 600, Loss: 0.556, Test Accuracy = 88.870%
# Epoch: 6, Mini-Batches Completed: 700, Loss: 0.546, Test Accuracy = 88.170%
# Epoch: 6, Mini-Batches Completed: 800, Loss: 0.566, Test Accuracy = 88.750%
# Epoch: 6, Mini-Batches Completed: 900, Loss: 0.551, Test Accuracy = 88.910%
# Epoch: 6, Mini-Batches Completed: 1000, Loss: 0.524, Test Accuracy = 88.770%
# Epoch: 6, Mini-Batches Completed: 1100, Loss: 0.517, Test Accuracy = 88.990%
# Epoch: 6, Mini-Batches Completed: 1200, Loss: 0.545, Test Accuracy = 88.400%
# Epoch: 6, Mini-Batches Completed: 1300, Loss: 0.538, Test Accuracy = 89.460%
# Epoch: 6, Mini-Batches Completed: 1400, Loss: 0.536, Test Accuracy = 89.090%
# Epoch: 6, Mini-Batches Completed: 1500, Loss: 0.561, Test Accuracy = 88.670%
# Epoch: 6, Mini-Batches Completed: 1600, Loss: 0.540, Test Accuracy = 89.260%
# Epoch: 6, Mini-Batches Completed: 1700, Loss: 0.523, Test Accuracy = 89.000%
# Epoch: 6, Mini-Batches Completed: 1800, Loss: 0.523, Test Accuracy = 89.430%
# Starting Epoch: 7...
# Epoch: 7, Mini-Batches Completed: 100, Loss: 0.508, Test Accuracy = 89.580%
# Epoch: 7, Mini-Batches Completed: 200, Loss: 0.525, Test Accuracy = 89.640%
# Epoch: 7, Mini-Batches Completed: 300, Loss: 0.538, Test Accuracy = 89.220%
# Epoch: 7, Mini-Batches Completed: 400, Loss: 0.503, Test Accuracy = 89.790%
# Epoch: 7, Mini-Batches Completed: 500, Loss: 0.501, Test Accuracy = 89.490%
# Epoch: 7, Mini-Batches Completed: 600, Loss: 0.492, Test Accuracy = 89.690%
# Epoch: 7, Mini-Batches Completed: 700, Loss: 0.499, Test Accuracy = 89.740%
# Epoch: 7, Mini-Batches Completed: 800, Loss: 0.471, Test Accuracy = 89.580%
# Epoch: 7, Mini-Batches Completed: 900, Loss: 0.505, Test Accuracy = 89.920%
# Epoch: 7, Mini-Batches Completed: 1000, Loss: 0.522, Test Accuracy = 89.700%
# Epoch: 7, Mini-Batches Completed: 1100, Loss: 0.498, Test Accuracy = 88.680%
# Epoch: 7, Mini-Batches Completed: 1200, Loss: 0.523, Test Accuracy = 89.570%
# Epoch: 7, Mini-Batches Completed: 1300, Loss: 0.470, Test Accuracy = 89.640%
# Epoch: 7, Mini-Batches Completed: 1400, Loss: 0.557, Test Accuracy = 89.650%
# Epoch: 7, Mini-Batches Completed: 1500, Loss: 0.457, Test Accuracy = 89.540%
# Epoch: 7, Mini-Batches Completed: 1600, Loss: 0.516, Test Accuracy = 89.950%
# Epoch: 7, Mini-Batches Completed: 1700, Loss: 0.463, Test Accuracy = 90.120%
# Epoch: 7, Mini-Batches Completed: 1800, Loss: 0.495, Test Accuracy = 90.060%
# Starting Epoch: 8...
# Epoch: 8, Mini-Batches Completed: 100, Loss: 0.465, Test Accuracy = 89.650%
# Epoch: 8, Mini-Batches Completed: 200, Loss: 0.482, Test Accuracy = 89.470%
# Epoch: 8, Mini-Batches Completed: 300, Loss: 0.484, Test Accuracy = 90.260%
# Epoch: 8, Mini-Batches Completed: 400, Loss: 0.507, Test Accuracy = 90.090%
# Epoch: 8, Mini-Batches Completed: 500, Loss: 0.452, Test Accuracy = 90.110%
# Epoch: 8, Mini-Batches Completed: 600, Loss: 0.480, Test Accuracy = 89.770%
# Epoch: 8, Mini-Batches Completed: 700, Loss: 0.491, Test Accuracy = 89.840%
# Epoch: 8, Mini-Batches Completed: 800, Loss: 0.461, Test Accuracy = 89.970%
# Epoch: 8, Mini-Batches Completed: 900, Loss: 0.485, Test Accuracy = 90.140%
# Epoch: 8, Mini-Batches Completed: 1000, Loss: 0.422, Test Accuracy = 89.610%
# Epoch: 8, Mini-Batches Completed: 1100, Loss: 0.500, Test Accuracy = 90.050%
# Epoch: 8, Mini-Batches Completed: 1200, Loss: 0.474, Test Accuracy = 90.030%
# Epoch: 8, Mini-Batches Completed: 1300, Loss: 0.472, Test Accuracy = 89.880%
# Epoch: 8, Mini-Batches Completed: 1400, Loss: 0.499, Test Accuracy = 89.750%
# Epoch: 8, Mini-Batches Completed: 1500, Loss: 0.480, Test Accuracy = 89.660%
# Epoch: 8, Mini-Batches Completed: 1600, Loss: 0.441, Test Accuracy = 90.370%
# Epoch: 8, Mini-Batches Completed: 1700, Loss: 0.478, Test Accuracy = 89.950%
# Epoch: 8, Mini-Batches Completed: 1800, Loss: 0.417, Test Accuracy = 89.490%
# Starting Epoch: 9...
# Epoch: 9, Mini-Batches Completed: 100, Loss: 0.437, Test Accuracy = 90.430%
# Epoch: 9, Mini-Batches Completed: 200, Loss: 0.419, Test Accuracy = 90.130%
# Epoch: 9, Mini-Batches Completed: 300, Loss: 0.437, Test Accuracy = 90.180%
# Epoch: 9, Mini-Batches Completed: 400, Loss: 0.453, Test Accuracy = 90.350%
# Epoch: 9, Mini-Batches Completed: 500, Loss: 0.460, Test Accuracy = 90.110%
# Epoch: 9, Mini-Batches Completed: 600, Loss: 0.401, Test Accuracy = 90.000%
# Epoch: 9, Mini-Batches Completed: 700, Loss: 0.409, Test Accuracy = 90.360%
# Epoch: 9, Mini-Batches Completed: 800, Loss: 0.438, Test Accuracy = 90.190%
# Epoch: 9, Mini-Batches Completed: 900, Loss: 0.422, Test Accuracy = 89.920%
# Epoch: 9, Mini-Batches Completed: 1000, Loss: 0.439, Test Accuracy = 90.390%
# Epoch: 9, Mini-Batches Completed: 1100, Loss: 0.471, Test Accuracy = 90.160%
# Epoch: 9, Mini-Batches Completed: 1200, Loss: 0.455, Test Accuracy = 90.140%
# Epoch: 9, Mini-Batches Completed: 1300, Loss: 0.442, Test Accuracy = 90.610%
# Epoch: 9, Mini-Batches Completed: 1400, Loss: 0.432, Test Accuracy = 90.170%
# Epoch: 9, Mini-Batches Completed: 1500, Loss: 0.428, Test Accuracy = 90.370%
# Epoch: 9, Mini-Batches Completed: 1600, Loss: 0.485, Test Accuracy = 90.120%
# Epoch: 9, Mini-Batches Completed: 1700, Loss: 0.425, Test Accuracy = 89.870%
# Epoch: 9, Mini-Batches Completed: 1800, Loss: 0.430, Test Accuracy = 89.760%
# Starting Epoch: 10...
# Epoch: 10, Mini-Batches Completed: 100, Loss: 0.418, Test Accuracy = 90.870%
# Epoch: 10, Mini-Batches Completed: 200, Loss: 0.426, Test Accuracy = 90.210%
# Epoch: 10, Mini-Batches Completed: 300, Loss: 0.368, Test Accuracy = 90.390%
# Epoch: 10, Mini-Batches Completed: 400, Loss: 0.421, Test Accuracy = 90.820%
# Epoch: 10, Mini-Batches Completed: 500, Loss: 0.421, Test Accuracy = 90.920%
# Epoch: 10, Mini-Batches Completed: 600, Loss: 0.421, Test Accuracy = 90.570%
# Epoch: 10, Mini-Batches Completed: 700, Loss: 0.419, Test Accuracy = 90.570%
# Epoch: 10, Mini-Batches Completed: 800, Loss: 0.425, Test Accuracy = 90.780%
# Epoch: 10, Mini-Batches Completed: 900, Loss: 0.412, Test Accuracy = 90.460%
# Epoch: 10, Mini-Batches Completed: 1000, Loss: 0.432, Test Accuracy = 90.670%
# Epoch: 10, Mini-Batches Completed: 1100, Loss: 0.406, Test Accuracy = 90.270%
# Epoch: 10, Mini-Batches Completed: 1200, Loss: 0.421, Test Accuracy = 90.880%
# Epoch: 10, Mini-Batches Completed: 1300, Loss: 0.405, Test Accuracy = 90.530%
# Epoch: 10, Mini-Batches Completed: 1400, Loss: 0.413, Test Accuracy = 90.470%
# Epoch: 10, Mini-Batches Completed: 1500, Loss: 0.419, Test Accuracy = 90.920%
# Epoch: 10, Mini-Batches Completed: 1600, Loss: 0.434, Test Accuracy = 89.800%
# Epoch: 10, Mini-Batches Completed: 1700, Loss: 0.387, Test Accuracy = 90.860%
# Epoch: 10, Mini-Batches Completed: 1800, Loss: 0.410, Test Accuracy = 90.720%
# Starting Epoch: 11...
# Epoch: 11, Mini-Batches Completed: 100, Loss: 0.398, Test Accuracy = 90.510%
# Epoch: 11, Mini-Batches Completed: 200, Loss: 0.408, Test Accuracy = 90.860%
# Epoch: 11, Mini-Batches Completed: 300, Loss: 0.357, Test Accuracy = 91.020%
# Epoch: 11, Mini-Batches Completed: 400, Loss: 0.418, Test Accuracy = 91.050%
# Epoch: 11, Mini-Batches Completed: 500, Loss: 0.401, Test Accuracy = 90.140%
# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.400, Test Accuracy = 90.870%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.382, Test Accuracy = 90.950%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.399, Test Accuracy = 90.650%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.392, Test Accuracy = 91.110%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.365, Test Accuracy = 90.550%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.389, Test Accuracy = 91.160%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.417, Test Accuracy = 90.670%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.405, Test Accuracy = 91.010%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.350, Test Accuracy = 91.010%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.402, Test Accuracy = 90.180%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.386, Test Accuracy = 91.180%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.430, Test Accuracy = 90.820%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.389, Test Accuracy = 91.270%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.378, Test Accuracy = 90.840%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.405, Test Accuracy = 90.790%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.379, Test Accuracy = 91.060%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.359, Test Accuracy = 90.450%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.349, Test Accuracy = 91.280%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.375, Test Accuracy = 90.960%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.394, Test Accuracy = 90.950%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.371, Test Accuracy = 90.780%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.339, Test Accuracy = 91.450%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.364, Test Accuracy = 90.870%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.386, Test Accuracy = 91.000%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.360, Test Accuracy = 90.990%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.363, Test Accuracy = 90.680%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.360, Test Accuracy = 91.210%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.348, Test Accuracy = 90.890%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.358, Test Accuracy = 90.850%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.357, Test Accuracy = 91.060%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.396, Test Accuracy = 91.140%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.340, Test Accuracy = 90.960%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.320, Test Accuracy = 90.210%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.338, Test Accuracy = 90.900%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.355, Test Accuracy = 91.060%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.385, Test Accuracy = 91.290%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.354, Test Accuracy = 91.310%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.336, Test Accuracy = 91.270%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.361, Test Accuracy = 90.930%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.356, Test Accuracy = 91.180%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.348, Test Accuracy = 91.490%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.362, Test Accuracy = 91.000%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.365, Test Accuracy = 91.330%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.320, Test Accuracy = 90.960%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.367, Test Accuracy = 91.530%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.332, Test Accuracy = 91.630%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.327, Test Accuracy = 90.690%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.389, Test Accuracy = 91.390%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.330, Test Accuracy = 91.560%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.309, Test Accuracy = 91.070%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.341, Test Accuracy = 91.330%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.350, Test Accuracy = 90.420%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.296, Test Accuracy = 91.290%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.358, Test Accuracy = 91.230%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.329, Test Accuracy = 91.200%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.291, Test Accuracy = 91.760%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.337, Test Accuracy = 90.980%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.297, Test Accuracy = 91.500%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.342, Test Accuracy = 90.950%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.350, Test Accuracy = 91.100%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.320, Test Accuracy = 91.090%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.333, Test Accuracy = 91.510%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.333, Test Accuracy = 90.800%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.314, Test Accuracy = 91.610%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.315, Test Accuracy = 91.090%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.331, Test Accuracy = 91.480%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.346, Test Accuracy = 91.400%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.306, Test Accuracy = 91.070%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.299, Test Accuracy = 91.080%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.301, Test Accuracy = 91.090%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.298, Test Accuracy = 91.350%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.287, Test Accuracy = 91.260%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.275, Test Accuracy = 91.550%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.332, Test Accuracy = 90.090%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.333, Test Accuracy = 91.460%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.317, Test Accuracy = 91.440%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.293, Test Accuracy = 91.620%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.293, Test Accuracy = 91.460%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.313, Test Accuracy = 91.170%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.307, Test Accuracy = 91.370%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.300, Test Accuracy = 91.270%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.348, Test Accuracy = 90.830%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.311, Test Accuracy = 91.280%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.318, Test Accuracy = 91.880%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.285, Test Accuracy = 91.220%
# Finished Training

# %% [markdown]
# #### **Our Model's Accuracy**

# %%
correct = 0 
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 91.5%

# %% [markdown]
# #### **Our Training Plots**

# %%
# To create a plot with secondary y-axis we need to create a subplot
fig, ax1 = plt.subplots()

# Set title and x-axis label rotation
plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %% [markdown]
# #### **Saving Our Model's Weights**

# %%
PATH = './fashion_mnist_cnn_net.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# # **4. Data Augumentation**
#
# To introduce Data Augmentation to our training data we simply create new Transform functions.
#
# **Recall our previous transformation function**
#
# ```transform = transforms.Compose([transforms.ToTensor(),
#                                transforms.Normalize((0.5, ), (0.5, )) ])```
#
# ### **We are going to firstly demonstrate how Data Augmentation Affects Our Images**

# %%
import PIL
from torchvision import transforms

data_aug_transform = transforms.Compose([
        transforms.RandomAffine(degrees=10, translate=(0.05, 0.05), shear=5), 
        transforms.ColorJitter(hue=0.05, saturation=0.05),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),  # Removed 'resample' argument
        transforms.Grayscale(num_output_channels=1)
])

# %% [markdown]
# #### **Perform the Data Augmentatin on a Single Image using the function below to Visualize the effects**

# %%
from matplotlib.pyplot import figure, imshow, axis
from matplotlib.image import imread

def showAugmentations(image, augmentations = 6):
    fig = figure()
    for i in range(augmentations):
        a = fig.add_subplot(1,augmentations,i+1)
        img = data_aug_transform(image)
        imshow(img ,cmap='Greys_r')
        axis('off')

# %%
# Load the first Image from our training data as a numpy array
image = trainset.data[1].numpy()

# Convert it to PIL image's format
img_pil = PIL.Image.fromarray(image)

showAugmentations(img_pil, 8)
