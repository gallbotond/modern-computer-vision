# %% [markdown]
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/logo_MCV_W.png)
#
# # **Regularisation in PyTorch - Part 2**
# ### **Now we use a few Regularisation methods on our Fashion-MNIST CNN**
#
# ![](https://github.com/rajeevratan84/ModernComputerVision/raw/main/CleanShot%202020-12-02%20at%204.01.54%402x.png)
# ---
#
#
#
# ---
#
#
# In this lesson, we first learn to create a **simple Convolutional Neural Network model** in PyTorch and train it to **classify images in the Fashion-MNIST Dataset**, now **WITH** the use of any regularisation methods.
# 1. Import PyTorch libraries, define our Transformers, Load our dataset and Visualize our images.
# 2. Build a Simple CNN with the following **Regularisation** methods:
#   - L2 Regularisation
#   - Data Augmentation
#   - Dropout
#   - BatchNorm
# 3. Training our CNN with Regularisation

# %% [markdown]
# # **1. Import PyTorch libraries, Define Transfomers and Load & Visualise Dataset**

# %%
# Import PyTorch
import torch
import PIL
import numpy as np

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
# Out:
# GPU available: True

# %%
device = 'cuda' #'cpu' if no GPU available

# %% [markdown]
# # **2. Building a CNN with Regulisation**
# ## **Implementing Data Augmentation**
#
# #### **Understanding What Our Transforms Do**
#
# 1. Our Transforms are applied to an image or batch of images everytime it's loaded.
# 2. These new images aren't saved, they're generated or 'altered' everytime a batch is loaded
#
# #### **NOTE**
#
# We don't apply the same augmentations to our Test or Validation Datasets. Therefore, we keep separate transformation functions (see below) for our Train and Validation/Test data.

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomAffine(degrees=10, translate=(0.05, 0.05), shear=5),
        transforms.ColorJitter(hue=0.05, saturation=0.05),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15),
        transforms.Grayscale(num_output_channels=1),
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,)),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ])
}

# %% [markdown]
# ### **Fetch and Create our Data Loaders**

# %%
# Load our Train Data and specify what transform to use when loading
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=data_transforms['train'])

# Load our Test Data and specify what transform to use when loading
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=data_transforms['val'])

# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

# %% [markdown]
# ### **Adding Dropout**
#
# In Convolutional Neural Networks Dropout is commonly added after CONV-RELU Layers.
#
# E.g. CONV->RELU->**DROPOUT**
#
# #### **Dropout Recommendations**
#
# In CNN's values of 0.1 to 0.3 have been found to work well.
#
# ### **Adding BatchNorm**
#
# In CNNs **BatchNorm** is best used between the Conv Layer and the activation function layer (ReLU)
# When used with Dropout, the recommended order is:
#
# CONV_1 -> **BatchNorm** -> ReLU -> Dropout - CONV_2
#
# **NOTE** BatchNorm's input arguement is the **output** size of the previous layer.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        # Adding BatchNorm, using 32 as the input since 32 was the output of our first Conv layer
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3)
        # Adding BatchNorm, using 64 as the input since 64 was the output of our first Conv layer
        self.conv2_bn = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)
        # Defining our dropout function with a rate of 0.2
        # We can apply this after any layer, but it's best suited after ReLU
        self.dropOut = nn.Dropout(0.2)

    def forward(self, x):
        x = F.relu(self.conv1_bn(self.conv1(x)))
        x = self.dropOut(x)
        x = self.dropOut(F.relu(self.conv2_bn(self.conv2(x))))

        x = self.pool(x)
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (dropOut): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### **Adding L2 Regularisation**
#
#
# L2 regularisation on the parameters/weights of the model is directly included in most optimizers, including optim.SGD.
#
# It can be controlled with the **weight_decay** parameter as can be seen in the [SGD documentation](http://pytorch.org/docs/optim.html#torch.optim.SGD).
#
# ```weight_decay``` (**float**, optional) – weight decay *(L2 penalty) (default: 0)*
#
# **Good L2 Values range from 0.1 to 0.0001**
#
# **NOTE:**
#
#  L1 regularization is not included by default in the optimizers, but could be added by including an extra loss nn.L1Loss in the weights of the model.

# %%
# We import our optimizer function
import torch.optim as optim

# We use Cross Entropy Loss as our loss function
criterion = nn.CrossEntropyLoss()

# For our gradient descent algorthim or Optimizer
# We use Stochastic Gradient Descent (SGD) with a learning rate of 0.001
# We set the momentum to be 0.9
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay = 0.001)

# %% [markdown]
# # **3. Training Our Model Using Regulisation Methods - Data Augmentation, Dropout, BatchNorm & L2 Regularisation**

# %%
# We loop over the traing dataset multiple times (each time is called an epoch)
epochs = 15

# Create some empty arrays to store logs 
epoch_log = []
loss_log = []
accuracy_log = []

# Iterate for a specified number of epochs
for epoch in range(epochs):  
    print(f'Starting Epoch: {epoch+1}...')

    # We keep adding or accumulating our loss after each mini-batch in running_loss
    running_loss = 0.0

    # We iterate through our trainloader iterator
    # Each cycle is a minibatch
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Move our data to GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # Clear the gradients before training by setting to zero
        # Required for a fresh start
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation 
        loss = criterion(outputs, labels) # Get Loss (quantify the difference between the results and predictions)
        loss.backward() # Back propagate to obtain the new gradients for all nodes
        optimizer.step() # Update the gradients/weights

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # show our loss every 50 mini-batches
            correct = 0 # Initialize our variable to hold the count for the correct predictions
            total = 0 # Initialize our variable to hold the count of the number of labels iterated

            # We don't need gradients for validation, so wrap in 
            # no_grad to save memory
            with torch.no_grad():
                # Iterate through the testloader iterator
                for data in testloader:
                    images, labels = data
                    # Move our data to GPU
                    images = images.to(device)
                    labels = labels.to(device)
                    
                    # Foward propagate our test data batch through our model
                    outputs = net(images)

                     # Get predictions from the maximum value
                    _, predicted = torch.max(outputs.data, 1)
                    # Keep adding the label size or length to the total variable
                    total += labels.size(0)
                    # Keep a running total of the number of predictions predicted correctly
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Epoch: {epoch_num}, Mini-Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini-Batches Completed: 100, Loss: 2.529, Test Accuracy = 70.560%
# Epoch: 1, Mini-Batches Completed: 200, Loss: 1.593, Test Accuracy = 76.410%
# Epoch: 1, Mini-Batches Completed: 300, Loss: 1.476, Test Accuracy = 71.290%
# Epoch: 1, Mini-Batches Completed: 400, Loss: 1.358, Test Accuracy = 77.110%
# Epoch: 1, Mini-Batches Completed: 500, Loss: 1.359, Test Accuracy = 78.590%
# Epoch: 1, Mini-Batches Completed: 600, Loss: 1.233, Test Accuracy = 74.060%
# Epoch: 1, Mini-Batches Completed: 700, Loss: 1.256, Test Accuracy = 80.890%
# Epoch: 1, Mini-Batches Completed: 800, Loss: 1.198, Test Accuracy = 79.290%
# Epoch: 1, Mini-Batches Completed: 900, Loss: 1.249, Test Accuracy = 78.950%
# Epoch: 1, Mini-Batches Completed: 1000, Loss: 1.147, Test Accuracy = 81.600%
# Epoch: 1, Mini-Batches Completed: 1100, Loss: 1.160, Test Accuracy = 80.410%
# Epoch: 1, Mini-Batches Completed: 1200, Loss: 1.139, Test Accuracy = 82.390%
# Epoch: 1, Mini-Batches Completed: 1300, Loss: 1.123, Test Accuracy = 82.080%
# Epoch: 1, Mini-Batches Completed: 1400, Loss: 1.176, Test Accuracy = 82.360%
# Epoch: 1, Mini-Batches Completed: 1500, Loss: 1.113, Test Accuracy = 82.650%
# Epoch: 1, Mini-Batches Completed: 1600, Loss: 1.046, Test Accuracy = 82.950%
# Epoch: 1, Mini-Batches Completed: 1700, Loss: 1.131, Test Accuracy = 83.310%
# Epoch: 1, Mini-Batches Completed: 1800, Loss: 1.109, Test Accuracy = 81.890%
# Starting Epoch: 2...
# Epoch: 2, Mini-Batches Completed: 100, Loss: 1.027, Test Accuracy = 84.190%
# Epoch: 2, Mini-Batches Completed: 200, Loss: 0.991, Test Accuracy = 83.830%
# Epoch: 2, Mini-Batches Completed: 300, Loss: 1.025, Test Accuracy = 84.420%
# Epoch: 2, Mini-Batches Completed: 400, Loss: 1.048, Test Accuracy = 84.630%
# Epoch: 2, Mini-Batches Completed: 500, Loss: 0.970, Test Accuracy = 83.670%
# Epoch: 2, Mini-Batches Completed: 600, Loss: 1.065, Test Accuracy = 83.730%
# Epoch: 2, Mini-Batches Completed: 700, Loss: 1.020, Test Accuracy = 84.580%
# Epoch: 2, Mini-Batches Completed: 800, Loss: 0.993, Test Accuracy = 85.000%
# Epoch: 2, Mini-Batches Completed: 900, Loss: 1.017, Test Accuracy = 84.510%
# Epoch: 2, Mini-Batches Completed: 1000, Loss: 0.978, Test Accuracy = 84.890%
# Epoch: 2, Mini-Batches Completed: 1100, Loss: 0.932, Test Accuracy = 84.820%
# Epoch: 2, Mini-Batches Completed: 1200, Loss: 0.972, Test Accuracy = 86.180%
# Epoch: 2, Mini-Batches Completed: 1300, Loss: 0.977, Test Accuracy = 84.480%
# Epoch: 2, Mini-Batches Completed: 1400, Loss: 0.914, Test Accuracy = 83.670%
# Epoch: 2, Mini-Batches Completed: 1500, Loss: 0.970, Test Accuracy = 84.990%
# Epoch: 2, Mini-Batches Completed: 1600, Loss: 0.930, Test Accuracy = 83.670%
# Epoch: 2, Mini-Batches Completed: 1700, Loss: 0.945, Test Accuracy = 84.510%
# Epoch: 2, Mini-Batches Completed: 1800, Loss: 0.954, Test Accuracy = 85.240%
# Starting Epoch: 3...
# Epoch: 3, Mini-Batches Completed: 100, Loss: 0.946, Test Accuracy = 84.950%
# Epoch: 3, Mini-Batches Completed: 200, Loss: 0.949, Test Accuracy = 85.850%
# Epoch: 3, Mini-Batches Completed: 300, Loss: 0.879, Test Accuracy = 85.730%
# Epoch: 3, Mini-Batches Completed: 400, Loss: 0.873, Test Accuracy = 85.740%
# Epoch: 3, Mini-Batches Completed: 500, Loss: 0.850, Test Accuracy = 84.950%
# Epoch: 3, Mini-Batches Completed: 600, Loss: 0.925, Test Accuracy = 85.340%
# Epoch: 3, Mini-Batches Completed: 700, Loss: 0.910, Test Accuracy = 86.280%
# Epoch: 3, Mini-Batches Completed: 800, Loss: 0.938, Test Accuracy = 85.580%
# Epoch: 3, Mini-Batches Completed: 900, Loss: 0.908, Test Accuracy = 85.320%
# Epoch: 3, Mini-Batches Completed: 1000, Loss: 0.885, Test Accuracy = 84.800%
# Epoch: 3, Mini-Batches Completed: 1100, Loss: 0.865, Test Accuracy = 85.790%
# Epoch: 3, Mini-Batches Completed: 1200, Loss: 0.896, Test Accuracy = 85.260%
# Epoch: 3, Mini-Batches Completed: 1300, Loss: 0.851, Test Accuracy = 86.450%
# Epoch: 3, Mini-Batches Completed: 1400, Loss: 0.806, Test Accuracy = 86.730%
# Epoch: 3, Mini-Batches Completed: 1500, Loss: 0.860, Test Accuracy = 85.640%
# Epoch: 3, Mini-Batches Completed: 1600, Loss: 0.867, Test Accuracy = 85.960%
# Epoch: 3, Mini-Batches Completed: 1700, Loss: 0.816, Test Accuracy = 85.890%
# Epoch: 3, Mini-Batches Completed: 1800, Loss: 0.851, Test Accuracy = 87.020%
# Starting Epoch: 4...
# Epoch: 4, Mini-Batches Completed: 100, Loss: 0.789, Test Accuracy = 86.130%
# Epoch: 4, Mini-Batches Completed: 200, Loss: 0.865, Test Accuracy = 86.530%
# Epoch: 4, Mini-Batches Completed: 300, Loss: 0.841, Test Accuracy = 87.150%
# Epoch: 4, Mini-Batches Completed: 400, Loss: 0.832, Test Accuracy = 85.930%
# Epoch: 4, Mini-Batches Completed: 500, Loss: 0.831, Test Accuracy = 86.710%
# Epoch: 4, Mini-Batches Completed: 600, Loss: 0.832, Test Accuracy = 86.520%
# Epoch: 4, Mini-Batches Completed: 700, Loss: 0.818, Test Accuracy = 86.310%
# Epoch: 4, Mini-Batches Completed: 800, Loss: 0.837, Test Accuracy = 86.610%
# Epoch: 4, Mini-Batches Completed: 900, Loss: 0.836, Test Accuracy = 86.410%
# Epoch: 4, Mini-Batches Completed: 1000, Loss: 0.823, Test Accuracy = 86.670%
# Epoch: 4, Mini-Batches Completed: 1100, Loss: 0.839, Test Accuracy = 86.670%
# Epoch: 4, Mini-Batches Completed: 1200, Loss: 0.815, Test Accuracy = 86.710%
# Epoch: 4, Mini-Batches Completed: 1300, Loss: 0.825, Test Accuracy = 85.420%
# Epoch: 4, Mini-Batches Completed: 1400, Loss: 0.861, Test Accuracy = 84.140%
# Epoch: 4, Mini-Batches Completed: 1500, Loss: 0.806, Test Accuracy = 86.270%
# Epoch: 4, Mini-Batches Completed: 1600, Loss: 0.791, Test Accuracy = 87.180%
# Epoch: 4, Mini-Batches Completed: 1700, Loss: 0.805, Test Accuracy = 86.300%
# Epoch: 4, Mini-Batches Completed: 1800, Loss: 0.808, Test Accuracy = 86.770%
# Starting Epoch: 5...
# Epoch: 5, Mini-Batches Completed: 100, Loss: 0.848, Test Accuracy = 87.410%
# Epoch: 5, Mini-Batches Completed: 200, Loss: 0.795, Test Accuracy = 87.670%
# Epoch: 5, Mini-Batches Completed: 300, Loss: 0.818, Test Accuracy = 83.520%
# Epoch: 5, Mini-Batches Completed: 400, Loss: 0.791, Test Accuracy = 87.360%
# Epoch: 5, Mini-Batches Completed: 500, Loss: 0.742, Test Accuracy = 86.990%
# Epoch: 5, Mini-Batches Completed: 600, Loss: 0.778, Test Accuracy = 87.010%
# Epoch: 5, Mini-Batches Completed: 700, Loss: 0.779, Test Accuracy = 87.470%
# Epoch: 5, Mini-Batches Completed: 800, Loss: 0.811, Test Accuracy = 86.370%
# Epoch: 5, Mini-Batches Completed: 900, Loss: 0.773, Test Accuracy = 86.690%
# Epoch: 5, Mini-Batches Completed: 1000, Loss: 0.784, Test Accuracy = 87.210%
# Epoch: 5, Mini-Batches Completed: 1100, Loss: 0.848, Test Accuracy = 86.760%
# Epoch: 5, Mini-Batches Completed: 1200, Loss: 0.815, Test Accuracy = 87.620%
# Epoch: 5, Mini-Batches Completed: 1300, Loss: 0.736, Test Accuracy = 87.500%
# Epoch: 5, Mini-Batches Completed: 1400, Loss: 0.778, Test Accuracy = 87.390%
# Epoch: 5, Mini-Batches Completed: 1500, Loss: 0.835, Test Accuracy = 87.570%
# Epoch: 5, Mini-Batches Completed: 1600, Loss: 0.767, Test Accuracy = 86.980%
# Epoch: 5, Mini-Batches Completed: 1700, Loss: 0.832, Test Accuracy = 87.220%
# Epoch: 5, Mini-Batches Completed: 1800, Loss: 0.754, Test Accuracy = 87.520%
# Starting Epoch: 6...
# Epoch: 6, Mini-Batches Completed: 100, Loss: 0.835, Test Accuracy = 88.090%
# Epoch: 6, Mini-Batches Completed: 200, Loss: 0

# Epoch: 11, Mini-Batches Completed: 600, Loss: 0.676, Test Accuracy = 88.740%
# Epoch: 11, Mini-Batches Completed: 700, Loss: 0.677, Test Accuracy = 88.420%
# Epoch: 11, Mini-Batches Completed: 800, Loss: 0.700, Test Accuracy = 88.810%
# Epoch: 11, Mini-Batches Completed: 900, Loss: 0.692, Test Accuracy = 88.740%
# Epoch: 11, Mini-Batches Completed: 1000, Loss: 0.647, Test Accuracy = 88.790%
# Epoch: 11, Mini-Batches Completed: 1100, Loss: 0.638, Test Accuracy = 89.020%
# Epoch: 11, Mini-Batches Completed: 1200, Loss: 0.648, Test Accuracy = 88.720%
# Epoch: 11, Mini-Batches Completed: 1300, Loss: 0.617, Test Accuracy = 87.040%
# Epoch: 11, Mini-Batches Completed: 1400, Loss: 0.661, Test Accuracy = 88.800%
# Epoch: 11, Mini-Batches Completed: 1500, Loss: 0.716, Test Accuracy = 87.650%
# Epoch: 11, Mini-Batches Completed: 1600, Loss: 0.702, Test Accuracy = 89.380%
# Epoch: 11, Mini-Batches Completed: 1700, Loss: 0.622, Test Accuracy = 89.400%
# Epoch: 11, Mini-Batches Completed: 1800, Loss: 0.655, Test Accuracy = 89.230%
# Starting Epoch: 12...
# Epoch: 12, Mini-Batches Completed: 100, Loss: 0.629, Test Accuracy = 89.000%
# Epoch: 12, Mini-Batches Completed: 200, Loss: 0.622, Test Accuracy = 89.470%
# Epoch: 12, Mini-Batches Completed: 300, Loss: 0.692, Test Accuracy = 88.770%
# Epoch: 12, Mini-Batches Completed: 400, Loss: 0.669, Test Accuracy = 89.410%
# Epoch: 12, Mini-Batches Completed: 500, Loss: 0.633, Test Accuracy = 89.350%
# Epoch: 12, Mini-Batches Completed: 600, Loss: 0.622, Test Accuracy = 89.020%
# Epoch: 12, Mini-Batches Completed: 700, Loss: 0.692, Test Accuracy = 88.840%
# Epoch: 12, Mini-Batches Completed: 800, Loss: 0.651, Test Accuracy = 88.960%
# Epoch: 12, Mini-Batches Completed: 900, Loss: 0.664, Test Accuracy = 88.610%
# Epoch: 12, Mini-Batches Completed: 1000, Loss: 0.632, Test Accuracy = 88.710%
# Epoch: 12, Mini-Batches Completed: 1100, Loss: 0.692, Test Accuracy = 86.200%
# Epoch: 12, Mini-Batches Completed: 1200, Loss: 0.660, Test Accuracy = 89.620%
# Epoch: 12, Mini-Batches Completed: 1300, Loss: 0.694, Test Accuracy = 87.370%
# Epoch: 12, Mini-Batches Completed: 1400, Loss: 0.683, Test Accuracy = 89.290%
# Epoch: 12, Mini-Batches Completed: 1500, Loss: 0.645, Test Accuracy = 89.120%
# Epoch: 12, Mini-Batches Completed: 1600, Loss: 0.636, Test Accuracy = 89.680%
# Epoch: 12, Mini-Batches Completed: 1700, Loss: 0.669, Test Accuracy = 89.150%
# Epoch: 12, Mini-Batches Completed: 1800, Loss: 0.610, Test Accuracy = 89.480%
# Starting Epoch: 13...
# Epoch: 13, Mini-Batches Completed: 100, Loss: 0.674, Test Accuracy = 89.510%
# Epoch: 13, Mini-Batches Completed: 200, Loss: 0.644, Test Accuracy = 89.240%
# Epoch: 13, Mini-Batches Completed: 300, Loss: 0.637, Test Accuracy = 89.080%
# Epoch: 13, Mini-Batches Completed: 400, Loss: 0.654, Test Accuracy = 89.120%
# Epoch: 13, Mini-Batches Completed: 500, Loss: 0.672, Test Accuracy = 89.000%
# Epoch: 13, Mini-Batches Completed: 600, Loss: 0.645, Test Accuracy = 89.210%
# Epoch: 13, Mini-Batches Completed: 700, Loss: 0.659, Test Accuracy = 89.110%
# Epoch: 13, Mini-Batches Completed: 800, Loss: 0.611, Test Accuracy = 89.160%
# Epoch: 13, Mini-Batches Completed: 900, Loss: 0.651, Test Accuracy = 89.260%
# Epoch: 13, Mini-Batches Completed: 1000, Loss: 0.655, Test Accuracy = 88.380%
# Epoch: 13, Mini-Batches Completed: 1100, Loss: 0.665, Test Accuracy = 89.470%
# Epoch: 13, Mini-Batches Completed: 1200, Loss: 0.659, Test Accuracy = 89.630%
# Epoch: 13, Mini-Batches Completed: 1300, Loss: 0.587, Test Accuracy = 89.860%
# Epoch: 13, Mini-Batches Completed: 1400, Loss: 0.623, Test Accuracy = 89.350%
# Epoch: 13, Mini-Batches Completed: 1500, Loss: 0.584, Test Accuracy = 88.790%
# Epoch: 13, Mini-Batches Completed: 1600, Loss: 0.666, Test Accuracy = 89.620%
# Epoch: 13, Mini-Batches Completed: 1700, Loss: 0.651, Test Accuracy = 89.450%
# Epoch: 13, Mini-Batches Completed: 1800, Loss: 0.684, Test Accuracy = 89.220%
# Starting Epoch: 14...
# Epoch: 14, Mini-Batches Completed: 100, Loss: 0.610, Test Accuracy = 88.370%
# Epoch: 14, Mini-Batches Completed: 200, Loss: 0.636, Test Accuracy = 89.670%
# Epoch: 14, Mini-Batches Completed: 300, Loss: 0.659, Test Accuracy = 88.870%
# Epoch: 14, Mini-Batches Completed: 400, Loss: 0.625, Test Accuracy = 89.670%
# Epoch: 14, Mini-Batches Completed: 500, Loss: 0.638, Test Accuracy = 89.510%
# Epoch: 14, Mini-Batches Completed: 600, Loss: 0.616, Test Accuracy = 89.360%
# Epoch: 14, Mini-Batches Completed: 700, Loss: 0.617, Test Accuracy = 89.400%
# Epoch: 14, Mini-Batches Completed: 800, Loss: 0.671, Test Accuracy = 89.100%
# Epoch: 14, Mini-Batches Completed: 900, Loss: 0.672, Test Accuracy = 88.730%
# Epoch: 14, Mini-Batches Completed: 1000, Loss: 0.679, Test Accuracy = 89.440%
# Epoch: 14, Mini-Batches Completed: 1100, Loss: 0.603, Test Accuracy = 89.640%
# Epoch: 14, Mini-Batches Completed: 1200, Loss: 0.654, Test Accuracy = 89.190%
# Epoch: 14, Mini-Batches Completed: 1300, Loss: 0.664, Test Accuracy = 89.110%
# Epoch: 14, Mini-Batches Completed: 1400, Loss: 0.628, Test Accuracy = 89.590%
# Epoch: 14, Mini-Batches Completed: 1500, Loss: 0.637, Test Accuracy = 89.670%
# Epoch: 14, Mini-Batches Completed: 1600, Loss: 0.640, Test Accuracy = 89.070%
# Epoch: 14, Mini-Batches Completed: 1700, Loss: 0.634, Test Accuracy = 89.280%
# Epoch: 14, Mini-Batches Completed: 1800, Loss: 0.615, Test Accuracy = 89.120%
# Starting Epoch: 15...
# Epoch: 15, Mini-Batches Completed: 100, Loss: 0.656, Test Accuracy = 89.490%
# Epoch: 15, Mini-Batches Completed: 200, Loss: 0.567, Test Accuracy = 89.180%
# Epoch: 15, Mini-Batches Completed: 300, Loss: 0.648, Test Accuracy = 88.920%
# Epoch: 15, Mini-Batches Completed: 400, Loss: 0.613, Test Accuracy = 89.870%
# Epoch: 15, Mini-Batches Completed: 500, Loss: 0.644, Test Accuracy = 89.620%
# Epoch: 15, Mini-Batches Completed: 600, Loss: 0.606, Test Accuracy = 89.300%
# Epoch: 15, Mini-Batches Completed: 700, Loss: 0.610, Test Accuracy = 89.550%
# Epoch: 15, Mini-Batches Completed: 800, Loss: 0.692, Test Accuracy = 89.150%
# Epoch: 15, Mini-Batches Completed: 900, Loss: 0.671, Test Accuracy = 89.710%
# Epoch: 15, Mini-Batches Completed: 1000, Loss: 0.603, Test Accuracy = 89.410%
# Epoch: 15, Mini-Batches Completed: 1100, Loss: 0.666, Test Accuracy = 89.490%
# Epoch: 15, Mini-Batches Completed: 1200, Loss: 0.617, Test Accuracy = 90.000%
# Epoch: 15, Mini-Batches Completed: 1300, Loss: 0.634, Test Accuracy = 89.590%
# Epoch: 15, Mini-Batches Completed: 1400, Loss: 0.605, Test Accuracy = 88.700%
# Epoch: 15, Mini-Batches Completed: 1500, Loss: 0.610, Test Accuracy = 89.610%
# Epoch: 15, Mini-Batches Completed: 1600, Loss: 0.606, Test Accuracy = 89.640%
# Epoch: 15, Mini-Batches Completed: 1700, Loss: 0.630, Test Accuracy = 89.550%
# Epoch: 15, Mini-Batches Completed: 1800, Loss: 0.622, Test Accuracy = 88.500%
# Finished Training

# %% [markdown]
# ### **Our Models Accuracy**

# %%
correct = 0 
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 89.43%

# %% [markdown]
# ### **Training Plots**

# %%
import matplotlib.pyplot as plt

# To create a plot with secondary y-axis we need to create a subplot
fig, ax1 = plt.subplots()

# Set title and x-axis label rotation
plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %% [markdown]
# #### **Early Stopping in PyTorch**
#
# https://github.com/Bjarten/early-stopping-pytorch
